# %%
import pandas as pd, json

raw = '{"no":3,"timestamp":"2026-09-24T18:35:55.201199+00:00",...}'
data = json.loads(raw)
df = pd.DataFrame([data])
df['timestamp'] = pd.to_datetime(df['timestamp'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd, json
#       2
#       3 raw = '{"no":3,"timestamp":"2026-09-24T18:35:55.201199+00:00",...}'
# ----> 4 data = json.loads(raw)
#       5 df = pd.DataFrame([data])
#       6 df['timestamp'] = pd.to_datetime(df['timestamp'])
#
# File ~/anaconda3/lib/python3.13/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...
